# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder

# %%
# Load in the pre-appointment-data
df = pd.read_csv('pre-appointment-data.csv')

# Mix the order of the data
df = df.sample(frac=1).reset_index(drop=True)

# Drop the columns that we don't need (symptom_cause, additional_symptoms, medical_history)
df = df.drop(['symptom_cause', 'additional_symptoms', 'medical_history'], axis=1)

# show the first 5 rows of the data
df.head()
# Out:
#                                    reason_for_visit  \
# 0                  Feeling overwhelmed and stressed
# 1                              Cough and chest pain
# 2                      Chest pain and chronic cough
# 3  I have been experiencing frequent stomach issues
# 4       Experiencing sleep problems and mood swings
#
#                                             symptoms  duration symptom_type  \
# 0                       Stress, anxiety, mood swings  2 months      Mental
# 1                           Cough, chest pain, fever    1 week  Respiratory
# 2  Coughing, chest pain, can't get enough air, fe...    1 year  Respiratory
# 3                         Nausea, vomiting, diarrhea   1 month    Digestive
# 4          Sleep problems, mood swings, irritability   3 weeks      Mental
#
#   symptom_severity                    appointment_expectations  \
# 0           Severe  To receive a diagnosis and start treatment
# 1         Moderate   To receive a diagnosis and treatment plan
# ...

# %%
# Encode the non-numeric columns
for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = LabelEncoder().fit_transform(df[col])

# %%
# Drop the label to create the X data
X = df.drop('symptom_type', axis=1)
X.head()
# Out:
#    reason_for_visit  symptoms  duration  symptom_severity  \
# 0                63       104         4                 2
# 1                23        21         1                 1
# 2                12        34         2                 2
# 3                84        88         0                 2
# 4                38       100         9                 0
#
#    appointment_expectations  health_concerns  health_experiences
# 0                        24               51                  53
# 1                        25                9                  35
# 2                        25               39                  25
# 3                        25               12                  49
# 4                        25               46                  10

# %%
# df symptom_type column
# Encode the labels
y = LabelEncoder().fit_transform(df['symptom_type'])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# Scale the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Show the first 5 rows of the scaled X_train data
print(X_train[:5])
# Out:
# [[ 0.27577031  0.88466474 -0.81765601  1.24191851 -0.0940496  -0.12577802
#   -0.0188321 ]
#  [-1.31309608 -0.76773796  0.30804715 -0.10958104 -0.34484852  0.91667018
#    1.09602794]
#  [ 0.27577031  0.91470842 -0.81765601  1.24191851 -0.0940496  -1.01930504
#    1.09602794]
#  [ 1.66602839  0.07348523 -1.0990818  -1.46108059 -0.84644636 -0.05131743
#   -0.0188321 ]
#  [-0.27040251  0.3438784   1.15232451 -1.46108059  3.16633637  0.46990667
#   -2.56708361]]

# %%
df.to_csv('preprocessed-data.csv', index=False)
